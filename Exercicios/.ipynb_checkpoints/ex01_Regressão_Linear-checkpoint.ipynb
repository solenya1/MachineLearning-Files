# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

df = pd.read_csv("/home/gab/Curso_ML/Exercicios/Datasets/kc_house_data.csv")

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0      5650     1.0           0     0          3      7        1180
# 1      7242     2.0           0     0          3      7        2170
# 2     10000     1.0           0     0          3      6         770
# 3      5000     1.0           0     0          5      7        1050
# 4      8080     1.0           0     0          3      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
# Verificando o nome de todas as colunas
df.columns.tolist()
# Out:
# ['id',
#  'date',
#  'price',
#  'bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'waterfront',
#  'view',
#  'condition',
#  'grade',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'zipcode',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15']

# %%
# Deletando todas as colunas que não Contribuem para o Algoritmo
df1 = df.drop(["id", "date","zipcode","lat", "long"], axis=1)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   price          21613 non-null  float64
#  1   bedrooms       21613 non-null  int64
#  2   bathrooms      21613 non-null  float64
#  3   sqft_living    21613 non-null  int64
#  4   sqft_lot       21613 non-null  int64
#  5   floors         21613 non-null  float64
#  6   waterfront     21613 non-null  int64
#  7   view           21613 non-null  int64
#  8   condition      21613 non-null  int64
#  9   grade          21613 non-null  int64
#  10  sqft_above     21613 non-null  int64
#  11  sqft_basement  21613 non-null  int64
#  12  yr_built       21613 non-null  int64
#  13  yr_renovated   21613 non-null  int64
#  14  sqft_living15  21613 non-null  int64
#  15  sqft_lot15     21613 non-null  int64
# dtypes: float64(3), int64(13)
# memory usage: 2.6 MB

# %%
df1.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
#    sqft_living15  sqft_lot15
# ...

# %% [markdown]
# ## Verificando Correlações entre os dados
#
# Como oque eu quero prever são os preços das casa vou fazer uma verificação de correlação apenas entre os preços afim de encontrar uma correlação forte positiva.

# %%
corr_matrix = df.corr()
corr_matrix["price"]
# Out:
# id              -0.016762
# price            1.000000
# bedrooms         0.308350
# bathrooms        0.525138
# sqft_living      0.702035
# sqft_lot         0.089661
# floors           0.256794
# waterfront       0.266369
# view             0.397293
# condition        0.036362
# grade            0.667434
# sqft_above       0.605567
# sqft_basement    0.323816
# yr_built         0.054012
# yr_renovated     0.126434
# zipcode         -0.053203
# lat              0.307003
# long             0.021626
# sqft_living15    0.585379
# sqft_lot15       0.082447
# Name: price, dtype: float64

# %% [markdown]
# Como pode se observar existe uma forte correlação positiva entre o preço das casas e a área construida delas.

# %% [markdown]
# ## Criando um Regressão Linear Simples

# %%
lr = LinearRegression()

# %%
# Separando os dados em dados de treino e teste.
X_treino = np.array(df1["sqft_living"], dtype=pd.Series).reshape(-1, 1)
y_treino = np.array(df1["price"], dtype=pd.Series).reshape(-1, 1)

X_teste = np.array(df1["sqft_living"], dtype=pd.Series).reshape(-1, 1)
y_teste = np.array(df1["price"], dtype=pd.Series).reshape(-1, 1)

lr.fit(X_treino, y_treino)
# Out:
# LinearRegression()

# %%
resultado = lr.score(X_teste, y_teste) # Determinado o R2

# %%
# Coeficiente Angular da Reta
coef_ang = lr.coef_
# Coeficiente Linear da Reta
coef_lin = lr.intercept_

# %%
print("Coeficiente de Determinação(R2)::",resultado)
print("Coeficiente Angular ::", coef_ang)
print("Coeficiente Linear ::",coef_lin)
# Out:
# Coeficiente de Determinação(R2):: 0.4928532179037931
# Coeficiente Angular :: [[280.6235679]]
# Coeficiente Linear :: [-43580.74309447]

# %% [markdown]
# ## Visualizando os Resultado

# %%
# Plotando o gráfico
plt.scatter(X_teste, y_teste, label="Data", color="lightgreen")
plt.plot(X_teste, lr.predict(X_teste), color="red", label="Predict")
plt.title("Visualização do Modelo")
plt.show()

# %% [markdown]
# # Solução Correta do Exercício

# %%
pd.set_option('display.max_columns', 21) # Comando Para visualizar todas Colunas
# Abrindo os arquivos 
arquivo = pd.read_csv("/home/gab/Curso_ML/Exercicios/Datasets/kc_house_data.csv")

# %%
arquivo.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# 0      5650     1.0           0     0          3      7        1180
# 1      7242     2.0           0     0          3      7        2170
# 2     10000     1.0           0     0          3      6         770
# 3      5000     1.0           0     0          5      7        1050
# 4      8080     1.0           0     0          3      8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
# Excluindo features irrelevantes
arquivo.drop("id", axis = 1, inplace = True)
arquivo.drop("date", axis = 1, inplace = True)
arquivo.drop("zipcode", axis = 1, inplace = True)
arquivo.drop("lat", axis = 1, inplace = True)
arquivo.drop("long", axis = 1, inplace = True)

# %%
# Visualizando os Arquivos Novamente agora Formatados
arquivo.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
#    sqft_living15  sqft_lot15
# ...

# %%
# Definindo váriaveis preditoras e variável target
y = arquivo["price"]
x = arquivo.drop(["price"], axis=1)

# %%
# Separando os dados emtreino e teste
x_treino, x_teste, y_treino, y_teste = train_test_split(x, y, test_size = 0.3, random_state=10)

# %%
# Criando o Modelo
modelo = LinearRegression()
modelo.fit(x_treino, y_treino)
# Out:
# LinearRegression()

# %%
# Calculando o coeficiente R2
resultado = modelo.score(x_teste, y_teste)
print('Coeficiente de determinação (R2) ::', resultado)
# Out:
# Coeficiente de determinação (R2) :: 0.6608668622831386
